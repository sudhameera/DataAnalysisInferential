# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Placement.csv')

# %%
data.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# # pre processing

# %% [markdown]
# #1)Replace the NaN values with correct value. And justify why you have chosen the same.

# %%
data.head(10)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5      6      M  55.00   Others  49.80   Others   Science     67.25
# 6      7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7      8      M  82.00  Central  64.00  Central   Science     66.00
# 8      9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9     10      M  58.00  Central  70.00  Central  Commerce     61.00
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No    55.00         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes    86.50        Mkt&Fin  66.28      Placed  200000.0
# ...

# %%
data['salary'].fillna(0,inplace=True)

# %%
data.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# #2)How many of them are not placed?

# %%
data['status'].value_counts()
# Out:
# Placed        148
# Not Placed     67
# Name: status, dtype: int64

# %% [markdown]
# #3)Find the reason for non placement from the dataset?

# %% [markdown]
# #4)What kind of relation between salary and mba_p

# %%
data.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
corr=data['mba_p'] .corr(data['salary'])

# %%
corr
# Out:
# 0.13982273892615565

# %% [markdown]
# #5)Which specialization is getting minimum salary?

# %%
data['salary'].min()
# Out:
# 0.0

# %%
data1=data[data['salary']!=0]

# %%
data1.head(10)
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0       1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1       2      M  79.33  Central  78.33   Others   Science     77.48
# 2       3      M  65.00  Central  68.00  Central      Arts     64.00
# 4       5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7       8      M  82.00  Central  64.00  Central   Science     66.00
# 8       9      M  73.00  Central  79.00  Central  Commerce     72.00
# 10     11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11     12      M  69.60  Central  68.40  Central  Commerce     78.30
# 13     14      F  77.00  Central  87.00  Central  Commerce     59.00
# 15     16      F  65.00  Central  75.00  Central  Commerce     69.00
#
#      degree_t workex  etest_p specialisation  mba_p  status    salary
# 0    Sci&Tech     No    55.00         Mkt&HR  58.80  Placed  270000.0
# ...

# %%
minsal = data1['salary'].min()

# %%
minsal
# Out:
# 200000.0

# %%
data1.loc[data1['salary']==200000.0]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 15      16      F  65.00  Central  75.00  Central  Commerce     69.00
# 44      45      F  77.00   Others  73.00   Others  Commerce     81.00
# 50      51      F  75.20  Central  73.20  Central   Science     68.40
# 107    108      M  82.00   Others  90.00   Others  Commerce     83.00
# 135    136      F  72.00  Central  56.00   Others   Science     69.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28  Placed  200000.0
# 15   Comm&Mgmt    Yes     72.0        Mkt&Fin  64.66  Placed  200000.0
# 44   Comm&Mgmt    Yes     89.0        Mkt&Fin  69.70  Placed  200000.0
# 50   Comm&Mgmt     No     65.0         Mkt&HR  62.98  Placed  200000.0
# 107  Comm&Mgmt     No     80.0         Mkt&HR  73.52  Placed  200000.0
# ...

# %% [markdown]
# #6)How many of them getting above 500000 salary?

# %%
def salary_check(data):
    
    above=[]

    for salary in data:
        if(salary>500000):
            above.append(salary)
    return above

# %%
salary_check(data['salary'])
# Out:
# [940000.0, 690000.0, 650000.0]

# %%
data.loc[data['salary']>500000]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119    120      M   60.8  Central  68.40  Central  Commerce      64.6
# 150    151      M   71.0  Central  58.66  Central   Science      58.0
# 177    178      F   73.0  Central  97.00   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %% [markdown]
# #7)Test the Analysis of Variance between etest_p and mba_p at signifance
# #level 5%.(Make decision using Hypothesis Testing)

# %%
# H0 = There is no significance between etest_p and mba_p
# H1 = There is significance between etest_p and mba_p

# %%
import scipy.stats as stats

# %%
stats.f_oneway(data['etest_p'],data['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
#since the p value is above we accept H0 that There is no significance difference between etest_p and mba_p.

# %% [markdown]
# #8)Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at
# #significance level of 5%.(Make decision using Hypothesis Testing)

# %%
# H0 = There is no similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary
# H1 = There is similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary

# %%
data=pd.get_dummies(data,drop_first=True)

# %%
data.columns
# Out:
# Index(['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary',
#        'gender_M', 'ssc_b_Others', 'hsc_b_Others', 'hsc_s_Commerce',
#        'hsc_s_Science', 'degree_t_Others', 'degree_t_Sci&Tech', 'workex_Yes',
#        'specialisation_Mkt&HR', 'status_Placed'],
#       dtype='object')

# %%
data.iloc[:,[8,11,14]]
# Out:
#      ssc_b_Others  hsc_s_Science  workex_Yes
# 0               1              0           0
# 1               0              1           1
# 2               0              0           0
# 3               0              1           0
# 4               0              0           0
# ..            ...            ...         ...
# 210             1              0           0
# 211             1              1           0
# 212             1              0           1
# 213             1              0           0
# 214             0              1           0
#
# [215 rows x 3 columns]

# %%
data=pd.get_dummies(data,drop_first=True)

# %%
data
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary  gender_M  \
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0         1
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0         1
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0         1
# 3        4  56.00  52.00     52.00     66.0  59.43       0.0         1
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0         1
# ..     ...    ...    ...       ...      ...    ...       ...       ...
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0         1
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0         1
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0         1
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0         0
# 214    215  62.00  58.00     53.00     89.0  60.22       0.0         1
#
#      ssc_b_Others  hsc_b_Others  hsc_s_Commerce  hsc_s_Science  \
# ...

# %%
data.columns
# Out:
# Index(['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary',
#        'gender_M', 'ssc_b_Others', 'hsc_b_Others', 'hsc_s_Commerce',
#        'hsc_s_Science', 'degree_t_Others', 'degree_t_Sci&Tech', 'workex_Yes',
#        'specialisation_Mkt&HR', 'status_Placed'],
#       dtype='object')

# %%
#rankings_pd.rename(columns = {'test':'TEST'}, inplace = True)
data.rename(columns={'specialisation_Mkt&HR':'specialisation','degree_t_Sci&Tech': 'degree'},inplace=True)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

ano2=ols('salary~specialisation + degree' , data=data).fit()
twoway=sm.stats.anova_lm(ano2,type=2)

# %%
twoway
# Out:
#                    df        sum_sq       mean_sq          F    PR(>F)
# specialisation    1.0  3.898793e+11  3.898793e+11  17.626508  0.000040
# degree            1.0  4.773661e+10  4.773661e+10   2.158180  0.143295
# Residual        212.0  4.689211e+12  2.211892e+10        NaN       NaN

# %%
#with respect to specialisation there is significance between salary and specialisation(Mkt&HR)
#with respect to degree there is no significance between salary and degree_t(Sci&Tech)

# %% [markdown]
# #9)Convert the normal distribution to standard normal distribution for salary column

# %%
Ndist=sns.distplot(data['salary'])
# Out:
# C:\Users\venka\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.

# %%
def stdNorDist(data):
    mean=data.mean()
    std=data.std()
    
    ##creating a list for the range of column values
    values=[value for value in data]
    
    ##finding Z score with the formula
    zscore=[((j-mean)/std) for j in values]
    
    #plot the normal distribution curve with distplot function
    sns.distplot(zscore,kde=True,kde_kws={'color':'blue'},color='grey')

# %%
stdNorDist(data['salary'])
# Out:
# C:\Users\venka\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   if sys.path[0] == "":

# %% [markdown]
# #10)What is the probability Density Function of the salary range from 700000 to 900000?

# %%
from matplotlib import pyplot
from scipy.stats import norm

# %%
def probability_density(data,startrange,endrange):

#using seaborn distribution plot by giving input data and mentioning the kernal distribution as True, color as green, grey 
#for data representation
    ax=sns.distplot(data,kde=True,kde_kws={'color':'green'},color='pink')
    
#with the distplot plot two vertical line mentioning the color as red, has start and end range
    pyplot.axvline(startrange,color='red')
    pyplot.axvline(endrange,color='red')

#finding mean and std deviation to plot the normal distribution curve
    mean=data.mean()
    std=data.std()
    print('mean=%.3f, standard deviation =%.3f' % (mean, std))
    
    Ndist=norm(mean,std)
    
    
#using inlinear feature for giving range of values and to store it in a list
    values=[value for value in range(startrange,endrange)]
    
#using pdf function plot probability distribution with the values stored in the list
    Pdist=[Ndist.pdf(value) for value in values]
    
#adding all the probability distribution values to find the probability
    probability=sum(Pdist)

    print('The probability in the range ({}- {})={}'.format(startrange,endrange,probability))
    
    return probability

# %%
probability_density(data['salary'] ,700000,900000)
# Out:
# C:\Users\venka\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """
# mean=288655.405, standard deviation =93457.452
# The probability in the range (700000- 900000)=5.377578376230696e-06
# 5.377578376230696e-06

# %% [markdown]
# #11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance
# #level of 5%.(Make decision using Hypothesis Testing)
#
# #Paired T-test- Dependent sample

# %%
#H0 = There is no similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p 
#H1 = There is similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p

# %%
from scipy.stats import ttest_rel
etest=data[data['degree_t']=='Sci&Tech']['etest_p']
mba=data[data['degree_t']=='Sci&Tech']['mba_p']
ttest_rel(etest,mba)
# Out:
# Ttest_relResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06)

# %%
#since the P value is higher, we accepts H0, that There is no similarity between the degree_t(Sci&Tech)with respect 
#to etest_p and mba_p

# %% [markdown]
# #12)Which parameter is highly correlated with salary?

# %%
data.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.063764
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.035330
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.076819
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.019272
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.178307
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %%
#when comparing the values in the table, etest pasmark and mba passmark is highly correlated with Salary.

# %% [markdown]
# #13) plot any useful graph and explain it.

# %% [markdown]
# #3)Find the reason for non placement from the dataset?

# %%
placed = data.loc[data['status']=='Placed']

# %%
placed
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
not_placed = data.loc[data['status']=='Not Placed']

# %%
not_placed
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
#data.plot(x="hsc_s", y=["salary", "degree_p"], kind="bar", figsize=(9, 8))

# %%
placed['mba_p'].mean()
# Out:
# 62.579391891891895

# %%
not_placed['mba_p'].mean()
# Out:
# 61.612835820895526

# %%
placed['mba_p'].median()
# Out:
# 62.245000000000005

# %%
not_placed['mba_p'].median()
# Out:
# 60.69

# %%
placed[placed['gender']=='M']
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 207    208      M  83.33  Central  78.00   Others  Commerce     61.00
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
#placed.plot(x="gender", y=["status",'degree_p'], kind="bar", figsize=(12, 13))

# %%
sns.countplot(x = 'workex',hue = "status",data = data)

# %%
sns.countplot(x = 'specialisation',hue = "status",data = data)

# %%
sns.countplot(x = 'gender',hue = "status",data = data)
